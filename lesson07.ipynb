# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (1.3.0)
# Requirement already satisfied: python-dotenv in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (1.1.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (4.12.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx2<3,>=2.0.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (2.12.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (2.11.10)
# Requirement already satisfied: sniffio<2,>=1 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (4.14.1)
# Requirement already satisfied: idna>=2.8 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.19)
# Requirement already satisfied: httpcore2==2.12.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from httpx2<3,>=2.0.0->anthropic) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from httpx2<3,>=2.0.0->anthropic) (0.10.4)
# Requirement already satisfied: h11>=0.16 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from httpcore2==2.12.0->httpx2<3,>=2.0.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
load_dotenv(override=True)

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5"
# Out:
# c:\Users\goran\AppData\Local\Programs\Python\Python313\Lib\ssl.py:524: UserWarning: Bad certificate in Windows certificate store: not enough data: cadata does not contain a certificate (_ssl.c:4218)
#   warnings.warn(f"Bad certificate in Windows certificate store: {exc!s}")

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def streamChat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system

    return client.messages.stream(**params)

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Write a 1 sentence description of a fake database")

with streamChat(messages) as stream:
    for text in stream.text_stream:
        print(text, end="")

# Get the complete message for database storage
final_message = stream.get_final_message()
# Out:
# A fake database is a simulated data storage system that contains artificially generated or placeholder information instead of real production data, commonly used for testing, development, or demonstration purposes.
