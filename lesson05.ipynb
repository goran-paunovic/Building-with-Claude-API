# %%
# %pip install anthropic python-dotenv
# Out:
# Collecting anthropic
#   Downloading anthropic-1.3.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: python-dotenv in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (1.1.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (4.12.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (0.17.0)
# Collecting httpx2<3,>=2.0.0 (from anthropic)
#   Downloading httpx2-2.12.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (2.11.10)
# Requirement already satisfied: sniffio<2,>=1 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (4.14.1)
# Requirement already satisfied: idna>=2.8 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Collecting httpcore2==2.12.0 (from httpx2<3,>=2.0.0->anthropic)
#   Downloading httpcore2-2.12.0-py3-none-any.whl.metadata (25 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->anthropic)
#   Downloading idna-3.19-py3-none-any.whl.metadata (9.2 kB)
# Collecting truststore>=0.10 (from httpx2<3,>=2.0.0->anthropic)
#   Downloading truststore-0.10.4-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: h11>=0.16 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from httpcore2==2.12.0->httpx2<3,>=2.0.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\goran\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.1)
# Downloading anthropic-1.3.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------------------------ --------------- 0.8/1.3 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 5.4 MB/s  0:00:00
# Downloading httpx2-2.12.0-py3-none-any.whl (95 kB)
# Downloading httpcore2-2.12.0-py3-none-any.whl (83 kB)
# Downloading idna-3.19-py3-none-any.whl (68 kB)
# Downloading truststore-0.10.4-py3-none-any.whl (18 kB)
# Installing collected packages: truststore, idna, httpcore2, httpx2, anthropic
#
#   Attempting uninstall: idna
#
#     Found existing installation: idna 3.10
#
#     Uninstalling idna-3.10:
#
#       Successfully uninstalled idna-3.10
#
#    -------- ------------------------------- 1/5 [idna]
#    ---------------- ----------------------- 2/5 [httpcore2]
#    ---------------- ----------------------- 2/5 [httpcore2]
#    ------------------------ --------------- 3/5 [httpx2]
#    ------------------------ --------------- 3/5 [httpx2]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    -------------------------------- ------- 4/5 [anthropic]
#    ---------------------------------------- 5/5 [anthropic]
#
# Successfully installed anthropic-1.3.0 httpcore2-2.12.0 httpx2-2.12.0 idna-3.19 truststore-0.10.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
load_dotenv(override=True)

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "How do I solve 5x + 2 = 3 for x?")

# Without system prompt
answer = chat(messages)

print("Claude's response:", answer)

# With system prompt
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
final_answer = chat(messages, system=system)

print("Claude's follow-up response:", final_answer)
# Out:
# Claude's response: # Solving 5x + 2 = 3
#
# To solve for x, isolate it on one side of the equation:
#
# **Step 1:** Subtract 2 from both sides
# ```
# 5x + 2 = 3
# 5x + 2 - 2 = 3 - 2
# 5x = 1
# ```
#
# **Step 2:** Divide both sides by 5
# ```
# 5x/5 = 1/5
# x = 1/5
# ```
#
# **Answer: x = 1/5** (or 0.2 in decimal form)
#
# **Check:** 5(1/5) + 2 = 1 + 2 = 3 ✓
# Claude's follow-up response: Good question! Let's work through this together step by step.
#
# First, think about what we're trying to do here. We want to get **x by itself** on one side of the equation.
#
# Right now we have: 5x + 2 = 3
#
# What do you notice is "attached" to the x term on the left side?
#
# And what could we do as a first step to start isolating x?
