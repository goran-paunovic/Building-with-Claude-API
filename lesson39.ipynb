# %% [markdown]
# # Extended thinking
#
# Extended thinking is Claude's advanced reasoning feature that gives the model time to work through complex problems before generating a final response. Think of it as Claude's "scratch paper" - you can see the reasoning process that leads to the answer, which helps with transparency and often results in better quality responses.

# %%
from dotenv import load_dotenv
load_dotenv(override=True)

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"

def add_messages(messages, message, role="user"):
    message = {"role": role, "content": message.content if isinstance(message, Message) else message}
    messages.append(message)

def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024,
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "stop_sequences": stop_sequences,
        "extra_body": {"temperature": temperature},
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget
        }
    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_messages(
    messages, 
    "Write a one pragraph guide to recursion.", 
    # thinking_test_str,
    role="user"
)

chat(messages, thinking=True)
# Out:
# Message(id='msg_011CesZQJgLKMNRLAAUYRSuP', container=None, content=[ThinkingBlock(signature='...', thinking='The user wants a one paragraph guide to recursion. This should be concise but cover the key concepts. I should explain what recursion is, mention the base case and recursive case, and perhaps include a helpful tip or common pitfall. Let me make it clear and accessible.', type='thinking'), TextBlock(citations=None, text='Recursion is a programming technique where a function calls itself to solve a problem by breaking it down into smaller, similar subproblems. Every recursive function needs two essential components: a **base case** (the stopping condition that prevents infinite loops) and a **recursive case** (where the function calls itself with modified parameters that move toward the base case). For example, calculating a factorial: `factorial(5) = 5 × factorial(4)`, which continues until reaching `factorial(1) = 1` (the base case). The key to mastering recursion is to trust that the recursive call will work correctly for the smaller problem and focus on: (1) defining what the simplest case looks like, (2) expressing the current problem in terms of a simpler version of itself, and (3) ensuring each recursive call progresses toward the base case. While recursion can make certain problems—like tree traversal, divide-and-conquer algorithms, or mathematical sequences—more elegant and intuitive than iterative solutions, be mindful that it consumes stack memory with each call and can be less efficient than loops for simple repetitive tasks.', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=46, output_tokens=310, output_tokens_details=OutputTokensDetails(thinking_tokens=62), server_tool_use=None, service_tier='standard'))
